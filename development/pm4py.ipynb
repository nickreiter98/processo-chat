# %%
import pm4py
from pm4py.discovery import discover_dfg

# %%
data = pm4py.read_xes("./data/xes/log_data_BPIC.xes")
# Out:
# parsing log, completed traces :: 100%|██████████| 1199/1199 [00:03<00:00, 367.83it/s]

# %%
data
# Out:
#       question         dateFinished                   dueDate  \
# 0        EMPTY  2014-04-14 00:00:00 2014-04-17 09:30:39+00:00
# 1        False  2014-04-14 00:00:00                       NaT
# 2         True  2014-04-14 00:00:00                       NaT
# 3        False  2014-04-14 00:00:00 2014-04-21 09:37:17+00:00
# 4         True  2014-04-14 00:00:00                       NaT
# ...        ...                  ...                       ...
# 52212    EMPTY  2014-07-11 00:00:00                       NaT
# 52213    EMPTY  2014-07-11 00:00:00                       NaT
# 52214    EMPTY  2014-07-11 00:00:00                       NaT
# 52215    EMPTY  2014-07-11 00:00:00                       NaT
# 52216    EMPTY  2014-07-11 00:00:00                       NaT
#
#            action_code                                  activityNameEN  \
# 0         01_HOOFD_010                register submission date request
# 1         01_HOOFD_011                            OLO messaging active
# ...

# %%
bpmn = pm4py.discovery.discover_bpmn_inductive(data)
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/home/nick/Documents/Masterthesis/Processo_Chat/.venv-linux/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_58775/3128299562.py", line 1, in <module>
#     bpmn = pm4py.discovery.discover_bpmn_inductive(data)
#   File "/home/nick/Documents/Masterthesis/Processo_Chat/.venv-linux/lib/python3.10/site-packages/pm4py/discovery.py", line 558, in discover_bpmn_inductive
#     pt = discover_process_tree_inductive(
#   File "/home/nick/Documents/Masterthesis/Processo_Chat/.venv-linux/lib/python3.10/site-packages/pm4py/discovery.py", line 398, in discover_process_tree_inductive
#     return inductive_miner.apply(log, variant=variant, parameters=parameters)
# ...
